# %%
import sys
sys.path.append('/opt/ml/code')

# %%
import torchvision

# %%
m  = torchvision.models.resnet50(pretrained=True)

# %%
m
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
m.la
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
import os
import pandas as pd
from config import testDataDir
from data.data_loader import get_loader
from data.data_set import TestDataset

# %%
submission = pd.read_csv(os.path.join(testDataDir, 'info.csv'))
image_dir = os.path.join(testDataDir, 'images')
image_paths = [os.path.join(image_dir, img_id) for img_id in submission.ImageID]

# %%
dataset = TestDataset(image_paths)

# %%
loader = get_loader(data_set=dataset)
_iter = next(iter(loader))
print(_iter.shape)
# Out:
# torch.Size([20, 3, 512, 384])

# %%
loader = get_loader(data_set=dataset, batch_size=1)
iter_ = next(iter(loader))
iter_.shape

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold

# %%
X = np.array([[1, 2], [3, 4], [1, 2], [3, 4], [6, 10]])
y = np.array([0, 0, 1, 1, 2])

# %%
skf = StratifiedKFold(n_splits=2)
skf.get_n_splits(X, y)
# Out:
# 2

# %%
print(skf)
train_index, test_index = next(iter(skf.split(X, y)))
print("TRAIN:", train_index, "TEST:", test_index)
# Out:
# StratifiedKFold(n_splits=5, random_state=None, shuffle=False)
# TRAIN: [ 1396  1397  1398 ... 18897 18898 18899] TEST: [   0    1    2 ... 5797 5799 5802]

# %%
for train_index, test_index in skf.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
# Out:
# TRAIN: [1 3] TEST: [0 2 4]
# TRAIN: [0 2 4] TEST: [1 3]
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"

# %%
skf = StratifiedKFold()
from data.data_loader import train_img_iter_numworker_batch

# %%
from config import trainDataDir, trainDataImgPaths
import pandas as pd
import os
import numpy as np

# %%
train_info = pd.read_csv(os.path.join(trainDataDir, 'train_info_merged.csv'))
train_info[['fullpath', 'mask_label', 'age_label', 'gender_label', 'agg_label']]
# Out:
#                                                 fullpath  mask_label  \
# 0      /opt/ml/input/data/train/images_origin/000001_...           0
# 1      /opt/ml/input/data/train/images_origin/000001_...           0
# 2      /opt/ml/input/data/train/images_origin/000001_...           1
# 3      /opt/ml/input/data/train/images_origin/000001_...           0
# 4      /opt/ml/input/data/train/images_origin/000001_...           0
# ...                                                  ...         ...
# 18895  /opt/ml/input/data/train/images_origin/006959_...           1
# 18896  /opt/ml/input/data/train/images_origin/006959_...           0
# 18897  /opt/ml/input/data/train/images_origin/006959_...           0
# 18898  /opt/ml/input/data/train/images_origin/006959_...           0
# 18899  /opt/ml/input/data/train/images_origin/006959_...           2
#
#        age_label  gender_label  agg_label
# 0              1             1          4
# 1              1             1          4
# ...

# %%
print(len(trainDataImgPaths))
print(trainDataImgPaths[0])

sub_path, name = os.path.split(trainDataImgPaths[0])
_, path = os.path.split(sub_path)

print(path, name)
# Out:
# 18900
# /opt/ml/input/data/train/images_origin/003790_male_Asian_46/mask1.jpg
# 003790_male_Asian_46 mask1.jpg

# %%
paths = []
fullpaths = []

for imgPaths in trainDataImgPaths:
    fullpath = imgPaths
    sub_path, _ = os.path.split(imgPaths)
    _, path = os.path.split(sub_path)
    
    paths.append(path)
    fullpaths.append(fullpath)

df = pd.DataFrame({'path': paths, 'fullpath': fullpaths})
df
# Out:
#                        path                                           fullpath
# 0      003790_male_Asian_46  /opt/ml/input/data/train/images_origin/003790_...
# 1      003790_male_Asian_46  /opt/ml/input/data/train/images_origin/003790_...
# 2      003790_male_Asian_46  /opt/ml/input/data/train/images_origin/003790_...
# 3      003790_male_Asian_46  /opt/ml/input/data/train/images_origin/003790_...
# 4      003790_male_Asian_46  /opt/ml/input/data/train/images_origin/003790_...
# ...                     ...                                                ...
# 18895  001737_male_Asian_18  /opt/ml/input/data/train/images_origin/001737_...
# 18896  001737_male_Asian_18  /opt/ml/input/data/train/images_origin/001737_...
# 18897  001737_male_Asian_18  /opt/ml/input/data/train/images_origin/001737_...
# 18898  001737_male_Asian_18  /opt/ml/input/data/train/images_origin/001737_...
# 18899  001737_male_Asian_18  /opt/ml/input/data/train/images_origin/001737_...
#
# ...

# %%
merged = pd.merge(train_info, df)

# %%
merged
# Out:
#            id  gender   race  age                    path  \
# 0      000001  female  Asian   45  000001_female_Asian_45
# 1      000001  female  Asian   45  000001_female_Asian_45
# 2      000001  female  Asian   45  000001_female_Asian_45
# 3      000001  female  Asian   45  000001_female_Asian_45
# 4      000001  female  Asian   45  000001_female_Asian_45
# ...       ...     ...    ...  ...                     ...
# 18895  006959    male  Asian   19    006959_male_Asian_19
# 18896  006959    male  Asian   19    006959_male_Asian_19
# 18897  006959    male  Asian   19    006959_male_Asian_19
# 18898  006959    male  Asian   19    006959_male_Asian_19
# 18899  006959    male  Asian   19    006959_male_Asian_19
#
#                                                 fullpath
# 0      /opt/ml/input/data/train/images_origin/000001_...
# 1      /opt/ml/input/data/train/images_origin/000001_...
# 2      /opt/ml/input/data/train/images_origin/000001_...
# ...

# %%
# merged.to_csv(os.path.join(trainDataDir, 'train_info_merged.csv'), index=False)
merged = pd.read_csv(os.path.join(trainDataDir, 'train_info_merged.csv'))
fullpath = '/opt/ml/input/data/train/images_origin/000001_female_Asian_45/mask1.jpg'
merged[merged.fullpath == fullpath].agg_label.values[-1]
# Out:
# 4

# %%
m_info.to_csv(os.path.join(trainDataDir, 'train_info_merged.csv'), index=False)
# m_info = pd.read_csv(os.path.join(trainDataDir, 'train_info_merged.csv'))

# %%
m_info
# Out:
#            id  gender   race  age                    path  \
# 0      000001  female  Asian   45  000001_female_Asian_45
# 1      000001  female  Asian   45  000001_female_Asian_45
# 2      000001  female  Asian   45  000001_female_Asian_45
# 3      000001  female  Asian   45  000001_female_Asian_45
# 4      000001  female  Asian   45  000001_female_Asian_45
# ...       ...     ...    ...  ...                     ...
# 18895  006959    male  Asian   19    006959_male_Asian_19
# 18896  006959    male  Asian   19    006959_male_Asian_19
# 18897  006959    male  Asian   19    006959_male_Asian_19
# 18898  006959    male  Asian   19    006959_male_Asian_19
# 18899  006959    male  Asian   19    006959_male_Asian_19
#
#                                                 fullpath  mask_label  \
# 0      /opt/ml/input/data/train/images_origin/000001_...           0
# 1      /opt/ml/input/data/train/images_origin/000001_...           0
# ...

# %%
def maskLabel(fullpath):
    label = 0
    _, name = os.path.split(fullpath)
    
    if name.startswith('incorrect'):
        label = 1
    elif name.startswith('normal'):
        label = 2
    return label

m_info['mask_label'] = m_info.fullpath.map(maskLabel)

# %%
m_info.groupby('mask_label').count()
# Out:
#                id  gender   race    age   path  fullpath
# mask_label
# 0           13500   13500  13500  13500  13500     13500
# 1            2700    2700   2700   2700   2700      2700
# 2            2700    2700   2700   2700   2700      2700

# %%
def ageLabel(age):
    label = 0
    if 30 <= age < 60:
        label = 1
    elif age >= 60:
        label = 2
    return label

m_info['age_label'] = m_info.age.map(ageLabel)

# %%
print(m_info.groupby('age_label').count())
# Out:
#              id  gender  race   age  path  fullpath  mask_label
# age_label
# 0          8967    8967  8967  8967  8967      8967        8967
# 1          8589    8589  8589  8589  8589      8589        8589
# 2          1344    1344  1344  1344  1344      1344        1344

# %%
def genderLabel(gender):
    label = 0
    if gender == 'female':
        label = 1
    return label

m_info['gender_label'] = m_info.gender.map(genderLabel)

# %%
print(m_info.groupby('gender_label').count())
# Out:
#                  id  gender   race    age   path  fullpath  mask_label  \
# gender_label
# 0              7294    7294   7294   7294   7294      7294        7294
# 1             11606   11606  11606  11606  11606     11606       11606
#
#               age_label
# gender_label
# 0                  7294
# 1                 11606

# %%
def aggLabel(row):
    print(row)
    label = row.mask_label * 6
    label += row.gender_label * 3
    label += row.age_label * 1
    return label

m_info['agg_label'] = m_info.mask_label * 6 + m_info.gender_label*3 + m_info.age_label

# %%
print(m_info.groupby('agg_label').count())
m_info.to_csv(os.path.join(trainDataDir, 'train_info_merged.csv'), index=False)
# Out:
#              id  gender  race   age  path  fullpath  mask_label  age_label  \
# agg_label
# 0          2745    2745  2745  2745  2745      2745        2745       2745
# 1          2050    2050  2050  2050  2050      2050        2050       2050
# 2           415     415   415   415   415       415         415        415
# 3          3660    3660  3660  3660  3660      3660        3660       3660
# 4          4085    4085  4085  4085  4085      4085        4085       4085
# 5           545     545   545   545   545       545         545        545
# 6           549     549   549   549   549       549         549        549
# 7           410     410   410   410   410       410         410        410
# 8            83      83    83    83    83        83          83         83
# 9           732     732   732   732   732       732         732        732
# 10          817     817   817   817   817       817         817        817
# ...

# %%
from data.data_set import MergedTrainDataSet
from data.data_loader import get_loader
train_set = MergedTrainDataSet()
iter_ = get_loader(train_set)

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold()

# %%
n_samples = len(train_set)
X = np.zeros(n_samples)
y = train_set.train_info.agg_label.values

# %%
print(n_samples, len(y))
# Out:
# 18900 18900

# %%
for train_idx, test_idx in skf.split(X, y):
    print(f'train_idx ({train_idx.shape}) : {train_idx} ')
    print(f'test_idx  ({test_idx.shape}) : {test_idx}')
    print(train_set.train_info.loc[train_idx].fullpath.values)
# Out:
# train_idx ((15120,)) : [ 1396  1397  1398 ... 18897 18898 18899]
# test_idx  ((3780,)) : [   0    1    2 ... 5797 5799 5802]
# ['/opt/ml/input/data/train/images_origin/000592_female_Asian_57/mask2.jpg'
#  '/opt/ml/input/data/train/images_origin/000592_female_Asian_57/mask5.jpg'
#  '/opt/ml/input/data/train/images_origin/000592_female_Asian_57/mask4.jpg'
#  ...
#  '/opt/ml/input/data/train/images_origin/006959_male_Asian_19/mask5.jpg'
#  '/opt/ml/input/data/train/images_origin/006959_male_Asian_19/mask4.jpg'
#  '/opt/ml/input/data/train/images_origin/006959_male_Asian_19/normal.jpg']
# train_idx ((15120,)) : [    0     1     2 ... 18897 18898 18899]
# test_idx  ((3780,)) : [ 1396  1397  1398 ... 13707 13708 13709]
# ['/opt/ml/input/data/train/images_origin/000001_female_Asian_45/mask1.jpg'
#  '/opt/ml/input/data/train/images_origin/000001_female_Asian_45/mask3.jpg'
#  '/opt/ml/input/data/train/images_origin/000001_female_Asian_45/incorrect_mask.jpg'
#  ...
# ...

# %%
from collections import Counter

for i, (inputs, labels) in enumerate(iter_):

    print(Counter(labels.numpy()))
    if i ==2 :
        break
# Out:
# Counter({1: 5, 0: 5, 3: 5, 7: 1, 13: 1, 6: 1, 12: 1, 9: 1})
# Counter({1: 9, 3: 5, 15: 2, 7: 2, 9: 1, 13: 1})
# Counter({0: 8, 4: 5, 6: 2, 1: 1, 13: 1, 10: 1, 16: 1, 12: 1})

# %%
a = np.array([1,2,3,4,5])
a[[1,2,3,4]]
# Out:
# array([2, 3, 4, 5])
